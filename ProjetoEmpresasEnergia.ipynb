# %%
# Import das bibliotecas necessárias para a análise

# Import da biblioteca que irá possibilitar acessar,
# análisar e manipular os dados do dataset.
import pandas as pd

# Import da biblioteca que possui uma grande variedade de gráficos
import seaborn as sns

# Import da biblioteca que possibilita criar e manipular gráficos
import matplotlib.pyplot as plt

# %%
# Conjunto de dados das ações de empresas do ramo energético na B3
base_dados = pd.read_excel('Dados_Empresas_Energia.xlsx')

# %%
# Visualizando as 5 primeiras linhas do dataset

print("5 PRIMEIRAS LINHAS DO DATASET")

base_dados.head()
# Out:
# 5 PRIMEIRAS LINHAS DO DATASET
#         Data  Petrobras  Aeris Energy     Alupar  AES Brasil      Cemig  \
# 0 2021-03-22  23.080000          9.28  24.600000       31.10  11.040665
# 1 2021-03-23  22.549999          8.94  24.910000       30.75  11.040665
# 2 2021-03-24  22.530001          9.02  24.610001       30.00  10.816444
# 3 2021-03-25  22.959999          9.20  24.990000       30.77  11.157260
# 4 2021-03-26  23.299999          9.10  25.299999       30.27  11.148292
#
#         Cesp
# 0  27.980000
# 1  27.700001
# 2  27.330000
# 3  27.809999
# 4  28.090000

# %%
# Visualizando as informações gerais do dataset

print("INFORMAÇÕES GERAIS DO DATASET")

base_dados.info()
# Out:
# INFORMAÇÕES GERAIS DO DATASET
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Data          251 non-null    datetime64[ns]
#  1   Petrobras     251 non-null    float64
#  2   Aeris Energy  251 non-null    float64
#  3   Alupar        251 non-null    float64
#  4   AES Brasil    251 non-null    float64
#  5   Cemig         251 non-null    float64
#  6   Cesp          251 non-null    float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 13.9 KB

# %%
# Série Temporal: setar o indice
# Esse trecho tem como objetivo definir a coluna 'Data' como
# indice do dataframe base_dados.
# Resumindo é um metodo da biblioteca pandas que irá transformar
# uma coluna em indice do Dataframe.
# Agora posso acessar as informações das linhas usando as datas 
# como chave para o indice. 
# O inplace=True ira aplicar a alteração no dataset original
base_dados.set_index('Data', inplace=True)

# %%
# Verificando se as datas viraram indices

print("VERFICANDO SE AS DATAS VIRARAM INDICES")

base_dados.head()
# Out:
# VERFICANDO SE AS DATAS VIRARAM INDICES
#             Petrobras  Aeris Energy     Alupar  AES Brasil      Cemig  \
# Data
# 2021-03-22  23.080000          9.28  24.600000       31.10  11.040665
# 2021-03-23  22.549999          8.94  24.910000       30.75  11.040665
# 2021-03-24  22.530001          9.02  24.610001       30.00  10.816444
# 2021-03-25  22.959999          9.20  24.990000       30.77  11.157260
# 2021-03-26  23.299999          9.10  25.299999       30.27  11.148292
#
#                  Cesp
# Data
# 2021-03-22  27.980000
# 2021-03-23  27.700001
# 2021-03-24  27.330000
# 2021-03-25  27.809999
# 2021-03-26  28.090000

# %%
# Antes de iniciar a construção do gráfico, vamos verificar os estilos
# disponiveis do plt.style.use

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
# Criação do gráfico

# Estilo do gráfico
plt.style.use('seaborn-v0_8-darkgrid')

# Tamanho da imagem do gráfico

plt.figure(figsize=(20, 7))

# titulo do gráfico: Será alinhado a esquerda, tera o tamanho da fonte 18,
# e a largura da fonte será 0.
plt.title('Análise de ações de empresas de energia', loc='left', fontsize=18, fontweight=0)


# Plot do grafico de linhas da petrobras: Terá a color da linha como verde,
# a margem da linha será 4 e a transparencia 0.7

# color: define a cor

# linewidth: Define a largura da linha

# alpha: define a transparência da cor da linha

plt.plot(base_dados.index, base_dados['Petrobras'], color='#008c4a', linewidth=4, alpha=0.7)

# plt.text: Comando do matplotlib que adiciona texto em um gráfico
# base_dados.index[-1]: Acessa o indice do dataframe que no nosso
# caso é a sequência das datas (valores da coluna 'Data')

# -1: seleciona o ultimo valor do indice. Ou seja, você está pegando
# o ultimo indice da série de dados em base_dados.

# base_dados['Petrobras']: Seleciona a coluna chamada 'Petrobras' do DataFrame

# tail(1): pega o ultimo valor dessa coluna. Ou seja, você está acessando
# o valor mais recente da coluna 'Petrobras'. O uso do Tail retorna uma
# série com apenas o último valor, mas como plt.text espera um valor
# escalar, ele pegará apenas esse valor.

# 'Petrobras': Este é o texto que será exibido no gráfico. O nome 'Petrobras'
# será colocado na posição especificada no gráfico.

# color: Defini a cor do texto

# size: Define o tamanho do texto. Definimos o tamanho 'large'

# horizontalalignment: Define o alinhamento horizontal do texto

plt.text(base_dados.index[-1], base_dados['Petrobras'].tail(1), 'Petrobras', color='red', size='large', horizontalalignment='left')

# Plot das outras colunas: Vamos criar um for que ira percorrer
# as colunas da base de dados com o intuito de criar/plotar as
# linhas grafico e os textos no gráfico

for colunas in base_dados.columns:
    
    plt.plot(base_dados.index, base_dados[colunas], color='gray', linewidth=2, alpha=0.7)
    
    plt.text(base_dados.index[-1], base_dados[colunas].tail(1), colunas, color='red', size='large', horizontalalignment='left')

# Rótulo do eixo X
plt.xlabel('Periodo')

# Rótulo do eixo Y
plt.ylabel('Preço do fechamento')
# Out:
# Text(0, 0.5, 'Preço do fechamento')
# C:\Users\caike\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\text.py:757: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   posy = float(self.convert_yunits(self._y))
# C:\Users\caike\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\matplotlib\text.py:898: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   y = float(self.convert_yunits(self._y))
